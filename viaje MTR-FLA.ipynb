# %% [markdown]
# # VIAJE DESDE MONTERÍA (CÓRDOBA) HASTA FLORENCIA (CAQUETÁ)

# %% [markdown]
# ### IMPORTAR LIBRERÍAS PYTHON

# %%
import folium
import os

# %% [markdown]
# ### TRAMO TOTAL DESDE MONTERIA A FLORENCIA

# %%
# Crear un objeto de mapa centrado en las coordenadas iniciales
mapa = folium.Map(location=[4.5709, -74.2973], zoom_start=6, title="Mapa del viaje Montería - Florencia")

# Lista de ubicaciones y popups
ubicaciones = [
    {"coordenadas": [8.755324462831581, -75.89909395591066], "popup": "Punto de salida: Montería - (Córdoba)"},

    {"coordenadas": [7.959675942418199, -75.20655830545536], "popup": "Caucasia - Antioquia"},

    {"coordenadas": [6.968731316464168, -75.42429392333105], "popup": "Yarumal- Antioquia"},

    {"coordenadas": [6.640164024759098, -75.44995757161223], "popup": "Santa Rosa de Osos - Antioquia (PETISCO, BUEN PUNTO PARA COMER)"},

    {"coordenadas": [6.484208100715497, -75.38705101192579], "popup": "Don Matías - Antioquia"},

    {"coordenadas": [6.437977017260511, -75.33846369281257], "popup": "Barbosa - Antioquia"},

    {"coordenadas": [6.536159257233253, -75.07590844325095], "popup": "Cisneros - Antioquia"},

    {"coordenadas": [6.49512366948926, -74.82311824525492], "popup": "San José del Nus- Antioquia"},

    {"coordenadas": [6.488196019575648, -74.40495625795943], "popup": "<a href='https://www.evernote.com/shard/s233/sh/51cf6e26-b292-9364-1350-37f41e6097bc/AECBFyKUtMRzgr3zZZtzCmqXVMm_A_nYYoTiq0g3UyvyI4U5_K5uPWHsgg'> Para dormir:Puerto Berrío - Antioquia (Hotel la Mansión)</a>"},

    {"coordenadas": [5.488746143065222, -74.63858245136448], "popup": "La Dorada-Caldas, Redoma el barrista, tomar el sentido como quien va para Honda"},

    {"coordenadas": [5.435400841999828, -74.63796503396352], "popup": "Variante la Dorada - Honda, para no entrar a la Dorada"},

    {"coordenadas": [5.417872113502243, -74.6869345437117], "popup": "Via hacia Honda- Tolima"},

    {"coordenadas": [5.2028492238222235, -74.72678037931378], "popup": "Honda- Tolima"},

    {"coordenadas": [4.904707950219132, -74.72896144383307], "popup": "Cambao- Tolima"},

    {"coordenadas": [4.5144206583382, -74.78916851937976], "popup": "Guataquí - Cundinamarca"},

    {"coordenadas": [4.247093126905553, -74.87166362438998], "popup": "Variante chichoral, romboy via Girardot - El espinal - Tolima"},

    {"coordenadas": [4.2528816227203, -74.83031101101027], "popup": "Girar a la derercha hacia el espinal - tolima"},

    {"coordenadas": [4.15996457324261, -74.8787309405236], "popup": "El Espinal - tolima"},

    {"coordenadas": [4.15996457324261, -74.8787309405236], "popup": "El Guamo- tolima"},

    {"coordenadas": [3.9216358107612623, -75.02133201379685], "popup": "Saldaña - tolima"},

    {"coordenadas": [3.6275041675331545, -75.09970626842593], "popup": "Natagaima- tolima"},

    {"coordenadas": [2.88861254894517, -75.2756215501869], "popup": "Neiva - Huila: Lo mejor es no entrar a neiva, coger la variante "},

    {"coordenadas": [2.779265199968648, -75.26019436239584], "popup": "Neiva - Rivera: Aquí pueden dormir"},

    {"coordenadas": [2.3792324348146567, -75.55390403991343], "popup": "Rivera - Gigante: Pa ver la mano del gigante"},

    {"coordenadas": [2.3792324348146567, -75.55390403991343], "popup": "Gigante - Garzón: tomar la variante"},

    {"coordenadas": [2.0590593455245, -75.7906211306375], "popup": "Garzón - Altamira"},

    {"coordenadas": [1.620704953731443, -75.61012014111849], "popup": "Altamira - Florencia"},

]

# Agregar marcadores con popups para cada ubicación en la lista
for ubicacion in ubicaciones:
    popup_content = folium.Popup(ubicacion["popup"], max_width=600)
    folium.Marker(location=ubicacion["coordenadas"], popup=ubicacion["popup"]).add_to(mapa)

# Agregar trazos entre las ubicaciones con el condicional for
for i in range(len(ubicaciones)-1):

    coord_1 = ubicaciones[i]["coordenadas"]
    coord_2 = ubicaciones[i+1]["coordenadas"]
    coord_3 = ubicaciones[i+1]["coordenadas"]
    coord_4 = ubicaciones[i+1]["coordenadas"]
    coord_5 = ubicaciones[i+1]["coordenadas"]
    coord_6 = ubicaciones[i+1]["coordenadas"]
    coord_7 = ubicaciones[i+1]["coordenadas"]
    coord_8 = ubicaciones[i+1]["coordenadas"]
    coord_9 = ubicaciones[i+1]["coordenadas"]
    coord_10= ubicaciones[i+1]["coordenadas"]
    coord_12= ubicaciones[i+1]["coordenadas"]
    coord_13= ubicaciones[i+1]["coordenadas"]
    coord_14= ubicaciones[i+1]["coordenadas"]
    coord_15= ubicaciones[i+1]["coordenadas"]
    coord_16= ubicaciones[i+1]["coordenadas"]
    coord_17= ubicaciones[i+1]["coordenadas"]
    coord_18= ubicaciones[i+1]["coordenadas"]
    coord_19= ubicaciones[i+1]["coordenadas"]
    coord_20= ubicaciones[i+1]["coordenadas"]
    coord_21= ubicaciones[i+1]["coordenadas"]
    coord_22= ubicaciones[i+1]["coordenadas"]
    coord_23= ubicaciones[i+1]["coordenadas"]
    coord_24= ubicaciones[i+1]["coordenadas"]
    coord_25= ubicaciones[i+1]["coordenadas"]
    coord_26= ubicaciones[i+1]["coordenadas"]
    coord_27= ubicaciones[i+1]["coordenadas"]

    folium.PolyLine(locations=[coord_1, coord_2], color='blue').add_to(mapa)

# Guardar el mapa como un archivo HTML
ruta="/home/wagner/Documents/Proyectos Ciencia de Datos/PROYECTO-NAVEGACION-DATOS-GEOESPACIALES/output_maps/mapa_completo_del_viaje.html"
mapa.save(ruta)
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9775e5f805d8b809af6ec0def98fd1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9775e5f805d8b809af6ec0def98fd1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9775e5f805d8b809af6ec0def98fd1a = L.map(
#                 &quot;map_c9775e5f805d8b809af6ec0def98fd1a&quot;,
#                 {
#                     center: [4.5709, -74.2973],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Mapa del viaje Monter\u00eda - Florencia&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_526ec3284ca309dd860bf80c70fa6c50 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c9775e5f805d8b809af6ec0def98fd1a);
#
#
#             var marker_104db1e1d46b3f11fb74d78008fc6f72 = L.marker(
#                 [8.755324462831581, -75.89909395591066],
#                 {}
#             ).addTo(map_c9775e5f805d8b809af6ec0def98fd1a);
#
#
#         var popup_d7ae888d6d11fc68937bfd68a478e7d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_404759cf21ec8c0b910ce1e72dd91e77 = $(`&lt;div id=&quot;html_404759cf21ec8c0b910ce1e72dd91e77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto de salida: Montería - (Córdoba)&lt;/div&gt;`)[0];
#                 popup_d7ae888d6d11fc68937bfd68a478e7d7.setContent(html_404759cf21ec8c0b910ce1e72dd91e77);
#
#
#
#         marker_104db1e1d46b3f11fb74d78008fc6f72.bindPopup(popup_d7ae888d6d11fc68937bfd68a478e7d7)
#         ;
#
#
#
#
#             var marker_2a2f25fad644c0f2791666418d22b5a2 = L.marker(
#                 [7.959675942418199, -75.20655830545536],
#                 {}
#             ).addTo(map_c9775e5f805d8b809af6ec0def98fd1a);
#
#
#         var popup_9011035bea8184fb2bb97e6ad9c41c5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c2fe42fc47e9d9ec2ddb65eec15d1d5 = $(`&lt;div id=&quot;html_6c2fe42fc47e9d9ec2ddb65eec15d1d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Caucasia - Antioquia&lt;/div&gt;`)[0];
#                 popup_9011035bea8184fb2bb97e6ad9c41c5e.setContent(html_6c2fe42fc47e9d9ec2ddb65eec15d1d5);
#
#
#
#         marker_2a2f25fad644c0f2791666418d22b5a2.bindPopup(popup_9011035bea8184fb2bb97e6ad9c41c5e)
#         ;
#
#
#
#
#             var marker_8d88e6bc2f16b2c96f7a8aae4ed2a829 = L.marker(
#                 [6.968731316464168, -75.42429392333105],
#                 {}
#             ).addTo(map_c9775e5f805d8b809af6ec0def98fd1a);
#
#
#         var popup_7b15734f83f9ef95e1ed5490cb6f9e8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_074b5bcc9c6b842d40d73cde17cd66cb = $(`&lt;div id=&quot;html_074b5bcc9c6b842d40d73cde17cd66cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Yarumal- Antioquia&lt;/div&gt;`)[0];
#                 popup_7b15734f83f9ef95e1ed5490cb6f9e8a.setContent(html_074b5bcc9c6b842d40d73cde17cd66cb);
#
#
#
#         marker_8d88e6bc2f16b2c96f7a8aae4ed2a829.bindPopup(popup_7b15734f83f9ef95e1ed5490cb6f9e8a)
#         ;
#
#
#
#
#             var marker_00a361bc6cf490ed4aa68d6fbee831f3 = L.marker(
#                 [6.640164024759098, -75.44995757161223],
#                 {}
#             ).addTo(map_c9775e5f805d8b809af6ec0def98fd1a);
#
#
#         var popup_db0dec553cb075a5c5408295aade999c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa9e1b71099339384c3c6f51360bbb0f = $(`&lt;div id=&quot;html_aa9e1b71099339384c3c6f51360bbb0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santa Rosa de Osos - Antioquia (PETISCO, BUEN PUNTO PARA COMER)&lt;/div&gt;`)[0];
#                 popup_db0dec553cb075a5c5408295aade999c.setContent(html_aa9e1b71099339384c3c6f51360bbb0f);
#
#
#
#         marker_00a361bc6cf490ed4aa68d6fbee831f3.bindPopup(popup_db0dec553cb075a5c5408295aade999c)
#         ;
#
#
#
#
#             var marker_53d69c196f7da06ddf9c96534121820c = L.marker(
#                 [6.484208100715497, -75.38705101192579],
#                 {}
#             ).addTo(map_c9775e5f805d8b809af6ec0def98fd1a);
#
#
#         var popup_9e5d166a366e33290673403d0c3ffa69 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1833e68ed1737736143bc874b4d1a277 = $(`&lt;div id=&quot;html_1833e68ed1737736143bc874b4d1a277&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Don Matías - Antioquia&lt;/div&gt;`)[0];
#                 popup_9e5d166a366e33290673403d0c3ffa69.setContent(html_1833e68ed1737736143bc874b4d1a277);

# %% [markdown]
# ### 1er TRAMO: MONTERÍA - PUERTO BERRÍO

# %%
# Crear un objeto de mapa centrado en las coordenadas iniciales
mapa = folium.Map(location=[4.5709, -74.2973], zoom_start=6, title="Mapa del viaje Montería - Puerto Berrío")

# Lista de ubicaciones y popups
ubicaciones = [
    {"coordenadas": [8.755324462831581, -75.89909395591066], "popup": "Punto de salida: Montería - (Córdoba)"},

    {"coordenadas": [7.959675942418199, -75.20655830545536], "popup": "Caucasia - Antioquia"},

    {"coordenadas": [6.968731316464168, -75.42429392333105], "popup": "Yarumal- Antioquia"},

    {"coordenadas": [6.640164024759098, -75.44995757161223], "popup": "Santa Rosa de Osos - Antioquia (PETISCO, BUEN PUNTO PARA COMER)"},

    {"coordenadas": [6.484208100715497, -75.38705101192579], "popup": "Don Matías - Antioquia"},

    {"coordenadas": [6.437977017260511, -75.33846369281257], "popup": "Barbosa - Antioquia"},

     {"coordenadas": [6.536159257233253, -75.07590844325095], "popup": "Cisneros - Antioquia"},

    {"coordenadas": [6.49512366948926, -74.82311824525492], "popup": "San José del Nus- Antioquia"},

    {"coordenadas": [6.488196019575648, -74.40495625795943], "popup": "<a href='https://www.evernote.com/shard/s233/sh/51cf6e26-b292-9364-1350-37f41e6097bc/AECBFyKUtMRzgr3zZZtzCmqXVMm_A_nYYoTiq0g3UyvyI4U5_K5uPWHsgg'> Para dormir: Puerto Berrío - Antioquia (Hotel la Mansión)</a>"},
]

# Agregar marcadores con popups para cada ubicación en la lista
for ubicacion in ubicaciones:
    folium.Marker(location=ubicacion["coordenadas"], popup=ubicacion["popup"]).add_to(mapa)

# Agregar trazos entre las ubicaciones
for i in range(len(ubicaciones)-1):
    
    coord_1 = ubicaciones[i]["coordenadas"]
    coord_2 = ubicaciones[i+1]["coordenadas"]
    coord_3 = ubicaciones[i+1]["coordenadas"]
    coord_4 = ubicaciones[i+1]["coordenadas"]
    coord_5 = ubicaciones[i+1]["coordenadas"]
    coord_6 = ubicaciones[i+1]["coordenadas"]
    coord_7 = ubicaciones[i+1]["coordenadas"]
    coord_8 = ubicaciones[i+1]["coordenadas"]
    coord_9 = ubicaciones[i+1]["coordenadas"]

    folium.PolyLine(locations=[coord_1, coord_2], color='blue').add_to(mapa)

# Guardar el mapa como un archivo HTML
mapa.save("/home/wagner/Documents/Proyectos Ciencia de Datos/PROYECTO-NAVEGACION-DATOS-GEOESPACIALES/output_maps/tramo_1.html")
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b1a5d26488b92e4d344e16262b8db28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b1a5d26488b92e4d344e16262b8db28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b1a5d26488b92e4d344e16262b8db28 = L.map(
#                 &quot;map_0b1a5d26488b92e4d344e16262b8db28&quot;,
#                 {
#                     center: [4.5709, -74.2973],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Mapa del viaje Monter\u00eda - Puerto Berr\u00edo&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf6c6733feacc1590105739c1bf7c9cd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b1a5d26488b92e4d344e16262b8db28);
#
#
#             var marker_57706bd2f2ef9fdfdb1687d302fea1c8 = L.marker(
#                 [8.755324462831581, -75.89909395591066],
#                 {}
#             ).addTo(map_0b1a5d26488b92e4d344e16262b8db28);
#
#
#         var popup_3874849d9873ee3abad84c92ea57e016 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a43ed7412e9a7ee3ce05629798dd75fe = $(`&lt;div id=&quot;html_a43ed7412e9a7ee3ce05629798dd75fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto de salida: Montería - (Córdoba)&lt;/div&gt;`)[0];
#                 popup_3874849d9873ee3abad84c92ea57e016.setContent(html_a43ed7412e9a7ee3ce05629798dd75fe);
#
#
#
#         marker_57706bd2f2ef9fdfdb1687d302fea1c8.bindPopup(popup_3874849d9873ee3abad84c92ea57e016)
#         ;
#
#
#
#
#             var marker_411571a79e7e43e549fb3de7d6207c52 = L.marker(
#                 [7.959675942418199, -75.20655830545536],
#                 {}
#             ).addTo(map_0b1a5d26488b92e4d344e16262b8db28);
#
#
#         var popup_9275c8e33b6d4c160c6398d483e6dd25 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d5fcf126f4704b0b0fa3b2b7e8848ea = $(`&lt;div id=&quot;html_9d5fcf126f4704b0b0fa3b2b7e8848ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Caucasia - Antioquia&lt;/div&gt;`)[0];
#                 popup_9275c8e33b6d4c160c6398d483e6dd25.setContent(html_9d5fcf126f4704b0b0fa3b2b7e8848ea);
#
#
#
#         marker_411571a79e7e43e549fb3de7d6207c52.bindPopup(popup_9275c8e33b6d4c160c6398d483e6dd25)
#         ;
#
#
#
#
#             var marker_33446c86dc45af8c8d514a6170a8fa61 = L.marker(
#                 [6.968731316464168, -75.42429392333105],
#                 {}
#             ).addTo(map_0b1a5d26488b92e4d344e16262b8db28);
#
#
#         var popup_35c64e97fad76cdf7257aa4fe6b9728b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a83315e2b5ae65f589c3f5ea5b4977a = $(`&lt;div id=&quot;html_2a83315e2b5ae65f589c3f5ea5b4977a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Yarumal- Antioquia&lt;/div&gt;`)[0];
#                 popup_35c64e97fad76cdf7257aa4fe6b9728b.setContent(html_2a83315e2b5ae65f589c3f5ea5b4977a);
#
#
#
#         marker_33446c86dc45af8c8d514a6170a8fa61.bindPopup(popup_35c64e97fad76cdf7257aa4fe6b9728b)
#         ;
#
#
#
#
#             var marker_c2c019fccdbe7cd7fd53a2ff51dc7895 = L.marker(
#                 [6.640164024759098, -75.44995757161223],
#                 {}
#             ).addTo(map_0b1a5d26488b92e4d344e16262b8db28);
#
#
#         var popup_799cbc45e4e2fb8eced1336867dca33b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b485837503809284800be9a55635cbf5 = $(`&lt;div id=&quot;html_b485837503809284800be9a55635cbf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santa Rosa de Osos - Antioquia (PETISCO, BUEN PUNTO PARA COMER)&lt;/div&gt;`)[0];
#                 popup_799cbc45e4e2fb8eced1336867dca33b.setContent(html_b485837503809284800be9a55635cbf5);
#
#
#
#         marker_c2c019fccdbe7cd7fd53a2ff51dc7895.bindPopup(popup_799cbc45e4e2fb8eced1336867dca33b)
#         ;
#
#
#
#
#             var marker_3fd7b141169ee3a2dc92a47bb1c843e1 = L.marker(
#                 [6.484208100715497, -75.38705101192579],
#                 {}
#             ).addTo(map_0b1a5d26488b92e4d344e16262b8db28);
#
#
#         var popup_ea21a0c691e6e56a171624615956c6e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c034f1362d9a7545e215665d35ed85e = $(`&lt;div id=&quot;html_4c034f1362d9a7545e215665d35ed85e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Don Matías - Antioquia&lt;/div&gt;`)[0];
#                 popup_ea21a0c691e6e56a171624615956c6e2.setContent(html_4c034f1362d9a7545e215665d35ed85e);

# %% [markdown]
# ### 2do TRAMO: PUERTO BERRÍO (ANTIOQUIA) - HONDA (TOLIMA)

# %%
# Crear un objeto de mapa centrado en las coordenadas iniciales
mapa = folium.Map(location=[4.5709, -74.2973], zoom_start=6, title="Mapa del viaje Puerto Berrío - Honda")

# Lista de ubicaciones y popups
ubicaciones = [

    {"coordenadas": [6.488196019575648, -74.40495625795943], "popup": "Puerto Berrío-(Antioquia)"},

    {"coordenadas": [5.488746143065222, -74.63858245136448], "popup": "La Dorada-Caldas, Redoma el barrista, tomar el sentido como quien va para Honda"},

    {"coordenadas": [5.435400841999828, -74.63796503396352], "popup": "Variante la Dorada - Honda, para no entrar a la Dorada"},

    {"coordenadas": [5.417872113502243, -74.6869345437117], "popup": "Via hacia Honda- Tolima"},
    
]

# Agregar marcadores con popups para cada ubicación en la lista
for ubicacion in ubicaciones:
    folium.Marker(location=ubicacion["coordenadas"], popup=ubicacion["popup"]).add_to(mapa)

# Agregar trazos entre las ubicaciones
for i in range(len(ubicaciones)-1):
    
    coord_1 = ubicaciones[i]["coordenadas"]
    coord_2 = ubicaciones[i+1]["coordenadas"]
    coord_3 = ubicaciones[i+1]["coordenadas"]
    coord_4 = ubicaciones[i+1]["coordenadas"]

    folium.PolyLine(locations=[coord_1, coord_2], color='blue').add_to(mapa)

# Guardar el mapa como un archivo HTML
mapa.save("/home/wagner/Documents/Proyectos Ciencia de Datos/PROYECTO-NAVEGACION-DATOS-GEOESPACIALES/output_maps/tramo_2.html")
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddef16ed74de13178146775609f4e0e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddef16ed74de13178146775609f4e0e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddef16ed74de13178146775609f4e0e9 = L.map(
#                 &quot;map_ddef16ed74de13178146775609f4e0e9&quot;,
#                 {
#                     center: [4.5709, -74.2973],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Mapa del viaje Puerto Berr\u00edo - Honda&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b7e8cd679d1b39cc048e5e61fc0311a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ddef16ed74de13178146775609f4e0e9);
#
#
#             var marker_97a8097238490966e7443e89c4e0db27 = L.marker(
#                 [6.488196019575648, -74.40495625795943],
#                 {}
#             ).addTo(map_ddef16ed74de13178146775609f4e0e9);
#
#
#         var popup_f5316595cba4f21de0f4d8aa92d57eee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae8f422f33954dae9a3782c681ae60e2 = $(`&lt;div id=&quot;html_ae8f422f33954dae9a3782c681ae60e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puerto Berrío-(Antioquia)&lt;/div&gt;`)[0];
#                 popup_f5316595cba4f21de0f4d8aa92d57eee.setContent(html_ae8f422f33954dae9a3782c681ae60e2);
#
#
#
#         marker_97a8097238490966e7443e89c4e0db27.bindPopup(popup_f5316595cba4f21de0f4d8aa92d57eee)
#         ;
#
#
#
#
#             var marker_5dc47b4ecd457ef56b1338637afdbd81 = L.marker(
#                 [5.488746143065222, -74.63858245136448],
#                 {}
#             ).addTo(map_ddef16ed74de13178146775609f4e0e9);
#
#
#         var popup_49a569971c4b5e44c3556174406f0f9b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5ea4340be04d34cf4d720e4dd0d23f48 = $(`&lt;div id=&quot;html_5ea4340be04d34cf4d720e4dd0d23f48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Dorada-Caldas, Redoma el barrista, tomar el sentido como quien va para Honda&lt;/div&gt;`)[0];
#                 popup_49a569971c4b5e44c3556174406f0f9b.setContent(html_5ea4340be04d34cf4d720e4dd0d23f48);
#
#
#
#         marker_5dc47b4ecd457ef56b1338637afdbd81.bindPopup(popup_49a569971c4b5e44c3556174406f0f9b)
#         ;
#
#
#
#
#             var marker_44a6b7924706f9688c6b63f9885790d5 = L.marker(
#                 [5.435400841999828, -74.63796503396352],
#                 {}
#             ).addTo(map_ddef16ed74de13178146775609f4e0e9);
#
#
#         var popup_12db57bae0dbc950371971acf7a378e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2d5a5d30516d8bfc4ab31b9b2cdff1a = $(`&lt;div id=&quot;html_c2d5a5d30516d8bfc4ab31b9b2cdff1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Variante la Dorada - Honda, para no entrar a la Dorada&lt;/div&gt;`)[0];
#                 popup_12db57bae0dbc950371971acf7a378e3.setContent(html_c2d5a5d30516d8bfc4ab31b9b2cdff1a);
#
#
#
#         marker_44a6b7924706f9688c6b63f9885790d5.bindPopup(popup_12db57bae0dbc950371971acf7a378e3)
#         ;
#
#
#
#
#             var marker_1bb24398a052dad0ff3e8f41c6c5c40f = L.marker(
#                 [5.417872113502243, -74.6869345437117],
#                 {}
#             ).addTo(map_ddef16ed74de13178146775609f4e0e9);
#
#
#         var popup_14a622d1d1ad82c771b6f1813b683035 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_936920e506bd268217b41c10086970fc = $(`&lt;div id=&quot;html_936920e506bd268217b41c10086970fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Via hacia Honda- Tolima&lt;/div&gt;`)[0];
#                 popup_14a622d1d1ad82c771b6f1813b683035.setContent(html_936920e506bd268217b41c10086970fc);
#
#
#
#         marker_1bb24398a052dad0ff3e8f41c6c5c40f.bindPopup(popup_14a622d1d1ad82c771b6f1813b683035)
#         ;
#
#
#
#
#             var poly_line_c9f86a6edee9ef3a033e201318ed6367 = L.polyline(
#                 [[6.488196019575648, -74.40495625795943], [5.488746143065222, -74.63858245136448]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&q

# %% [markdown]
# ### 3er TRAMO: HONDA (TOLIMA) - SALDAÑA (TOLIMA)

# %%
# Crear un objeto de mapa centrado en las coordenadas iniciales
mapa = folium.Map(location=[4.5709, -74.2973], zoom_start=6, title="Mapa del viaje Honda - Saldaña")

# Lista de ubicaciones y popups
ubicaciones = [

    {"coordenadas": [5.2028492238222235, -74.72678037931378], "popup": "Honda- Tolima"},

    {"coordenadas": [4.904707950219132, -74.72896144383307], "popup": "Cambao- Tolima"},

    {"coordenadas": [4.5144206583382, -74.78916851937976], "popup": "Guataquí - Cundinamarca"},

    {"coordenadas": [4.247093126905553, -74.87166362438998], "popup": "Variante chichoral, romboy via Girardot - El espinal - Tolima"},

    {"coordenadas": [4.2528816227203, -74.83031101101027], "popup": "Girar a la derercha hacia el espinal - tolima"},

    {"coordenadas": [4.15996457324261, -74.8787309405236], "popup": "El Espinal - tolima"},

    {"coordenadas": [4.15996457324261, -74.8787309405236], "popup": "El Guamo- tolima"},

    {"coordenadas": [3.9216358107612623, -75.02133201379685], "popup": "Saldaña - tolima"},

    
]

# Agregar marcadores con popups para cada ubicación en la lista
for ubicacion in ubicaciones:
    folium.Marker(location=ubicacion["coordenadas"], popup=ubicacion["popup"]).add_to(mapa)

# Agregar trazos entre las ubicaciones
for i in range(len(ubicaciones)-1):
    
    coord_1 = ubicaciones[i]["coordenadas"]
    coord_2 = ubicaciones[i+1]["coordenadas"]
    coord_3 = ubicaciones[i+1]["coordenadas"]
    coord_4 = ubicaciones[i+1]["coordenadas"]
    coord_5 = ubicaciones[i+1]["coordenadas"]
    coord_6 = ubicaciones[i+1]["coordenadas"]
    coord_7 = ubicaciones[i+1]["coordenadas"]
    coord_8 = ubicaciones[i+1]["coordenadas"]

    folium.PolyLine(locations=[coord_1, coord_2], color='blue').add_to(mapa)

# Guardar el mapa como un archivo HTML
mapa.save("/home/wagner/Documents/Proyectos Ciencia de Datos/PROYECTO-NAVEGACION-DATOS-GEOESPACIALES/output_maps/tramo_3.html")
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8c69d77b397a783c3ec2f73a45dd57f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8c69d77b397a783c3ec2f73a45dd57f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8c69d77b397a783c3ec2f73a45dd57f = L.map(
#                 &quot;map_d8c69d77b397a783c3ec2f73a45dd57f&quot;,
#                 {
#                     center: [4.5709, -74.2973],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Mapa del viaje Honda - Salda\u00f1a&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_253aa6416a2e5131abbc25605bbdf039 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8c69d77b397a783c3ec2f73a45dd57f);
#
#
#             var marker_3b94f1eecff99147518866792420d236 = L.marker(
#                 [5.2028492238222235, -74.72678037931378],
#                 {}
#             ).addTo(map_d8c69d77b397a783c3ec2f73a45dd57f);
#
#
#         var popup_ad5fd6987a407a3290e5f49e50e972e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_709d19f623ad3194130e0aaaee6ec1a0 = $(`&lt;div id=&quot;html_709d19f623ad3194130e0aaaee6ec1a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Honda- Tolima&lt;/div&gt;`)[0];
#                 popup_ad5fd6987a407a3290e5f49e50e972e0.setContent(html_709d19f623ad3194130e0aaaee6ec1a0);
#
#
#
#         marker_3b94f1eecff99147518866792420d236.bindPopup(popup_ad5fd6987a407a3290e5f49e50e972e0)
#         ;
#
#
#
#
#             var marker_8e8a7cf36787699bf637c54b9b330358 = L.marker(
#                 [4.904707950219132, -74.72896144383307],
#                 {}
#             ).addTo(map_d8c69d77b397a783c3ec2f73a45dd57f);
#
#
#         var popup_7f82c3522a7598648e22a400b93505c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30af421cc5e093bb3a12a38f7bcab72f = $(`&lt;div id=&quot;html_30af421cc5e093bb3a12a38f7bcab72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cambao- Tolima&lt;/div&gt;`)[0];
#                 popup_7f82c3522a7598648e22a400b93505c0.setContent(html_30af421cc5e093bb3a12a38f7bcab72f);
#
#
#
#         marker_8e8a7cf36787699bf637c54b9b330358.bindPopup(popup_7f82c3522a7598648e22a400b93505c0)
#         ;
#
#
#
#
#             var marker_0b36566c977308c291b3c6d6c9875632 = L.marker(
#                 [4.5144206583382, -74.78916851937976],
#                 {}
#             ).addTo(map_d8c69d77b397a783c3ec2f73a45dd57f);
#
#
#         var popup_18a34e03499f3cec7fe122fa43a4cdb2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25ce3dc2f0d8942a95d6285c5452c9b5 = $(`&lt;div id=&quot;html_25ce3dc2f0d8942a95d6285c5452c9b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Guataquí - Cundinamarca&lt;/div&gt;`)[0];
#                 popup_18a34e03499f3cec7fe122fa43a4cdb2.setContent(html_25ce3dc2f0d8942a95d6285c5452c9b5);
#
#
#
#         marker_0b36566c977308c291b3c6d6c9875632.bindPopup(popup_18a34e03499f3cec7fe122fa43a4cdb2)
#         ;
#
#
#
#
#             var marker_59251b621c7c5399943d9cf55c7ebc7f = L.marker(
#                 [4.247093126905553, -74.87166362438998],
#                 {}
#             ).addTo(map_d8c69d77b397a783c3ec2f73a45dd57f);
#
#
#         var popup_5d0f7df9ad8c2b340456f32110c8df66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6fbde2beea613a149b7c018ab5c7b5fb = $(`&lt;div id=&quot;html_6fbde2beea613a149b7c018ab5c7b5fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Variante chichoral, romboy via Girardot - El espinal - Tolima&lt;/div&gt;`)[0];
#                 popup_5d0f7df9ad8c2b340456f32110c8df66.setContent(html_6fbde2beea613a149b7c018ab5c7b5fb);
#
#
#
#         marker_59251b621c7c5399943d9cf55c7ebc7f.bindPopup(popup_5d0f7df9ad8c2b340456f32110c8df66)
#         ;
#
#
#
#
#             var marker_984fddd1bb7f491e455a6196bd9eeb78 = L.marker(
#                 [4.2528816227203, -74.83031101101027],
#                 {}
#             ).addTo(map_d8c69d77b397a783c3ec2f73a45dd57f);
#
#
#         var popup_fd575d961328e0bb044d038019b24c4d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3b4553bf190a0fb83c7d62fca5501af = $(`&lt;div id=&quot;html_f3b4553bf190a0fb83c7d62fca5501af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Girar a la derercha hacia el espinal - tolima&lt;/div&gt;`)[0];
#                 popup_fd575d961328e0bb044d038019b24c4d.setContent(html_f3b4553bf190a0fb83c7d62fca5501af);

# %% [markdown]
# ### 4to TRAMO: SALDAÑA (TOLIMA) - NEIVA (HUILA)

# %%
# Crear un objeto de mapa centrado en las coordenadas iniciales
mapa = folium.Map(location=[4.5709, -74.2973], zoom_start=6, title="Mapa del viaje Saldaña - Neiva")

# Lista de ubicaciones y popups
ubicaciones = [

    {"coordenadas": [3.9216358107612623, -75.02133201379685], "popup": "Saldaña - tolima"},

    {"coordenadas": [3.6275041675331545, -75.09970626842593], "popup": "Natagaima- tolima"},

    {"coordenadas": [2.88861254894517, -75.2756215501869], "popup": "Neiva - Huila: Lo mejor es no entrar a neiva, coger la variante "},
   
]

# Agregar marcadores con popups para cada ubicación en la lista
for ubicacion in ubicaciones:
    folium.Marker(location=ubicacion["coordenadas"], popup=ubicacion["popup"]).add_to(mapa)

# Agregar trazos entre las ubicaciones
for i in range(len(ubicaciones)-1):
    
    coord_1 = ubicaciones[i]["coordenadas"]
    coord_2 = ubicaciones[i+1]["coordenadas"]
    coord_3 = ubicaciones[i+1]["coordenadas"]

    folium.PolyLine(locations=[coord_1, coord_2], color='blue').add_to(mapa)

# Guardar el mapa como un archivo HTML
mapa.save("/home/wagner/Documents/Proyectos Ciencia de Datos/PROYECTO-NAVEGACION-DATOS-GEOESPACIALES/output_maps/tramo_4.html")
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8272e7a6571b56d9480baf003ceffbb0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8272e7a6571b56d9480baf003ceffbb0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8272e7a6571b56d9480baf003ceffbb0 = L.map(
#                 &quot;map_8272e7a6571b56d9480baf003ceffbb0&quot;,
#                 {
#                     center: [4.5709, -74.2973],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Mapa del viaje Salda\u00f1a - Neiva&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fff908b8d9e7c156f77af4dce9e6279c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8272e7a6571b56d9480baf003ceffbb0);
#
#
#             var marker_0a834b8de4b0745724a2c9c345a94904 = L.marker(
#                 [3.9216358107612623, -75.02133201379685],
#                 {}
#             ).addTo(map_8272e7a6571b56d9480baf003ceffbb0);
#
#
#         var popup_d139452525169e2021ec1711cea5ca24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_866de47b833f996ce5d3f4f719a69b26 = $(`&lt;div id=&quot;html_866de47b833f996ce5d3f4f719a69b26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Saldaña - tolima&lt;/div&gt;`)[0];
#                 popup_d139452525169e2021ec1711cea5ca24.setContent(html_866de47b833f996ce5d3f4f719a69b26);
#
#
#
#         marker_0a834b8de4b0745724a2c9c345a94904.bindPopup(popup_d139452525169e2021ec1711cea5ca24)
#         ;
#
#
#
#
#             var marker_c29cd9ff5a15d30afc7ae65ecb585775 = L.marker(
#                 [3.6275041675331545, -75.09970626842593],
#                 {}
#             ).addTo(map_8272e7a6571b56d9480baf003ceffbb0);
#
#
#         var popup_663b6bba09ae49c95d90436310e48ccd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a28ee9a74efbdc1c7a7aba3d1c7bbe4 = $(`&lt;div id=&quot;html_0a28ee9a74efbdc1c7a7aba3d1c7bbe4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Natagaima- tolima&lt;/div&gt;`)[0];
#                 popup_663b6bba09ae49c95d90436310e48ccd.setContent(html_0a28ee9a74efbdc1c7a7aba3d1c7bbe4);
#
#
#
#         marker_c29cd9ff5a15d30afc7ae65ecb585775.bindPopup(popup_663b6bba09ae49c95d90436310e48ccd)
#         ;
#
#
#
#
#             var marker_0571f65ce92ca8275fb12cc947cf3a93 = L.marker(
#                 [2.88861254894517, -75.2756215501869],
#                 {}
#             ).addTo(map_8272e7a6571b56d9480baf003ceffbb0);
#
#
#         var popup_1c7809f2150ce56e3e9f395a6b66175e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f52e0e993037eee3dbf053db2e1a3bcb = $(`&lt;div id=&quot;html_f52e0e993037eee3dbf053db2e1a3bcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Neiva - Huila: Lo mejor es no entrar a neiva, coger la variante &lt;/div&gt;`)[0];
#                 popup_1c7809f2150ce56e3e9f395a6b66175e.setContent(html_f52e0e993037eee3dbf053db2e1a3bcb);
#
#
#
#         marker_0571f65ce92ca8275fb12cc947cf3a93.bindPopup(popup_1c7809f2150ce56e3e9f395a6b66175e)
#         ;
#
#
#
#
#             var poly_line_cfb4a2971f00fc664ab4adfe638dbf08 = L.polyline(
#                 [[3.9216358107612623, -75.02133201379685], [3.6275041675331545, -75.09970626842593]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8272e7a6571b56d9480baf003ceffbb0);
#
#
#             var poly_line_5a09de9b87161da5fbf71b3e9c4828e7 = L.polyline(
#                 [[3.6275041675331545, -75.09970626842593], [2.88861254894517, -75.2756215501869]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8272e7a6571b56d9480baf003ceffbb0);
#
# &lt;/script&gt;
# &lt;/html&gt;"

# %% [markdown]
# ### 5to TRAMO: NEIVA (HUILA) - FLORENCIA (CAQUETÁ)

# %%
# Crear un objeto de mapa centrado en las coordenadas iniciales
mapa = folium.Map(location=[4.5709, -74.2973], zoom_start=6, title="Mapa del viaje Saldaña - Neiva")

# Lista de ubicaciones y popups
ubicaciones = [

    {"coordenadas": [2.88861254894517, -75.2756215501869], "popup": "Neiva - Huila: Lo mejor es no entrar a neiva, coger la variante "},

    {"coordenadas": [2.779265199968648, -75.26019436239584], "popup": "Neiva - Rivera: Aquí pueden dormir"},

    {"coordenadas": [2.3792324348146567, -75.55390403991343], "popup": "Rivera - Gigante: Pa ver la mano del gigante"},

    {"coordenadas": [2.3792324348146567, -75.55390403991343], "popup": "Gigante - Garzón: tomar la variante"},

    {"coordenadas": [2.0590593455245, -75.7906211306375], "popup": "Garzón - Altamira"},

    {"coordenadas": [1.620704953731443, -75.61012014111849], "popup": "Altamira - Florencia"},
   
]

# Agregar marcadores con popups para cada ubicación en la lista
for ubicacion in ubicaciones:
    folium.Marker(location=ubicacion["coordenadas"], popup=ubicacion["popup"]).add_to(mapa)

# Agregar trazos entre las ubicaciones
for i in range(len(ubicaciones)-1):
    
    coord_1 = ubicaciones[i]["coordenadas"]
    coord_2 = ubicaciones[i+1]["coordenadas"]
    coord_3 = ubicaciones[i+1]["coordenadas"]
    coord_4 = ubicaciones[i+1]["coordenadas"]
    coord_5 = ubicaciones[i+1]["coordenadas"]
    coord_6 = ubicaciones[i+1]["coordenadas"]

    folium.PolyLine(locations=[coord_1, coord_2], color='blue').add_to(mapa)

# Guardar el mapa como un archivo HTML
mapa.save("/home/wagner/Documents/Proyectos Ciencia de Datos/PROYECTO-NAVEGACION-DATOS-GEOESPACIALES/output_maps/tramo_4.html")
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71ab2919f03ce565f18aebba5e315fc2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71ab2919f03ce565f18aebba5e315fc2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71ab2919f03ce565f18aebba5e315fc2 = L.map(
#                 &quot;map_71ab2919f03ce565f18aebba5e315fc2&quot;,
#                 {
#                     center: [4.5709, -74.2973],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Mapa del viaje Salda\u00f1a - Neiva&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2479d4b2a97ceff1ee0534750c5c31ea = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_71ab2919f03ce565f18aebba5e315fc2);
#
#
#             var marker_073b051ed2556652e3d591228c22c165 = L.marker(
#                 [2.88861254894517, -75.2756215501869],
#                 {}
#             ).addTo(map_71ab2919f03ce565f18aebba5e315fc2);
#
#
#         var popup_4af4b15e755aba9da5f1386ae17c23ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71e6a1dc28d213c17acf7eaef0ff86e6 = $(`&lt;div id=&quot;html_71e6a1dc28d213c17acf7eaef0ff86e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Neiva - Huila: Lo mejor es no entrar a neiva, coger la variante &lt;/div&gt;`)[0];
#                 popup_4af4b15e755aba9da5f1386ae17c23ae.setContent(html_71e6a1dc28d213c17acf7eaef0ff86e6);
#
#
#
#         marker_073b051ed2556652e3d591228c22c165.bindPopup(popup_4af4b15e755aba9da5f1386ae17c23ae)
#         ;
#
#
#
#
#             var marker_3fd35733808da16e58aa3382f2d5f5a6 = L.marker(
#                 [2.779265199968648, -75.26019436239584],
#                 {}
#             ).addTo(map_71ab2919f03ce565f18aebba5e315fc2);
#
#
#         var popup_ed5376d86143a6600f1bd898c3154f9b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29b2656e7c615ed50baf4a70ef00d195 = $(`&lt;div id=&quot;html_29b2656e7c615ed50baf4a70ef00d195&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Neiva - Rivera: Aquí pueden dormir&lt;/div&gt;`)[0];
#                 popup_ed5376d86143a6600f1bd898c3154f9b.setContent(html_29b2656e7c615ed50baf4a70ef00d195);
#
#
#
#         marker_3fd35733808da16e58aa3382f2d5f5a6.bindPopup(popup_ed5376d86143a6600f1bd898c3154f9b)
#         ;
#
#
#
#
#             var marker_caf914bdab9c7daf41349270cbb59b3e = L.marker(
#                 [2.3792324348146567, -75.55390403991343],
#                 {}
#             ).addTo(map_71ab2919f03ce565f18aebba5e315fc2);
#
#
#         var popup_637379da075e483faaa31fcf6663684d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4aab17d5dfcd607e4ada224efe854f37 = $(`&lt;div id=&quot;html_4aab17d5dfcd607e4ada224efe854f37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rivera - Gigante: Pa ver la mano del gigante&lt;/div&gt;`)[0];
#                 popup_637379da075e483faaa31fcf6663684d.setContent(html_4aab17d5dfcd607e4ada224efe854f37);
#
#
#
#         marker_caf914bdab9c7daf41349270cbb59b3e.bindPopup(popup_637379da075e483faaa31fcf6663684d)
#         ;
#
#
#
#
#             var marker_a8bbd94a7a6dd78583945e3f0ebff71c = L.marker(
#                 [2.3792324348146567, -75.55390403991343],
#                 {}
#             ).addTo(map_71ab2919f03ce565f18aebba5e315fc2);
#
#
#         var popup_258c85e762968854177967743a6afd39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea9115c216ac1f5c97a2fd24ab3f253a = $(`&lt;div id=&quot;html_ea9115c216ac1f5c97a2fd24ab3f253a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gigante - Garzón: tomar la variante&lt;/div&gt;`)[0];
#                 popup_258c85e762968854177967743a6afd39.setContent(html_ea9115c216ac1f5c97a2fd24ab3f253a);
#
#
#
#         marker_a8bbd94a7a6dd78583945e3f0ebff71c.bindPopup(popup_258c85e762968854177967743a6afd39)
#         ;
#
#
#
#
#             var marker_d4bcfff6f2e0800c13ec0931596cc8a1 = L.marker(
#                 [2.0590593455245, -75.7906211306375],
#                 {}
#             ).addTo(map_71ab2919f03ce565f18aebba5e315fc2);
#
#
#         var popup_b8cf09427135c29cad0bac674ae09308 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4804289dc6623280c410d2d5776eac1c = $(`&lt;div id=&quot;html_4804289dc6623280c410d2d5776eac1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Garzón - Altamira&lt;/div&gt;`)[0];
#                 popup_b8cf09427135c29cad0bac674ae09308.setContent(html_4804289dc6623280c410d2d5776e

# %% [markdown]
# ### REFERENCIAS BIBLIOGRÁFICAS
